# %%
import pandas as pd 
df = pd.read_parquet('/home/yangzhilin/backtest/backtest_light/factor_values/xy.parquet')
df
# start_date = '2024-01-02'
# end_date = '2024-04-30'

# start_label = 1
# end_label = 288
# mask = (
#     ((df.index.get_level_values('date') > start_date) & (df.index.get_level_values('date') < end_date)) |
#     ((df.index.get_level_values('date') == start_date) & (df.index.get_level_values('Label') >= start_label)) |
#     ((df.index.get_level_values('date') == end_date) & (df.index.get_level_values('Label') <= end_label))
# )

# # 应用掩码进行筛选
# filtered_df = df.loc[mask]

# filtered_df
# Out:
# Uid               1000bonk-usdt  1000floki-usdt  1000lunc-usdt  1000pepe-usdt  \
# date       Label
# 2025-01-01 48          0.022538        0.034113       0.023281       0.100084
#            96          0.003464        0.016422       0.004539       0.050951
#            144        -0.010344        0.002172      -0.005598      -0.001689
#            192        -0.027494        0.003914      -0.005105       0.003567
#            240        -0.019940       -0.002665      -0.004885      -0.017423
#            288        -0.023736       -0.015350       0.004902      -0.037573
# 2025-01-02 48         -0.013678       -0.004235       0.015193      -0.018096
#            96          0.005555        0.000881       0.029629      -0.009790
#            144        -0.000397        0.006422       0.014312      -0.009786
#            192         0.017693        0.022243       0.017683       0.015267
#            240         0.045158        0.024971       0.012256       0.030749
# ...

# %%
import pandas as pd 
df = pd.read_parquet('/home/yangzhilin/backtest/backtest_light/factor_values/xy1.parquet')
df
# Out:
# Uid               1000bonk-usdt  1000floki-usdt  1000lunc-usdt  1000pepe-usdt  \
# date       Label
# 2024-01-01 48          0.003931        0.001873       0.003963       0.002535
#            96         -0.001215        0.022452      -0.008132       0.010815
#            144        -0.050959       -0.013418      -0.028507      -0.025879
#            192        -0.050418       -0.021407      -0.027672      -0.024307
#            240        -0.020592       -0.008807      -0.018816      -0.008857
# ...                         ...             ...            ...            ...
# 2025-01-01 96          0.003464        0.016422       0.004539       0.050951
#            144        -0.010344        0.002172      -0.005598      -0.001689
#            192        -0.027494        0.003914      -0.005105       0.003567
#            240        -0.019940       -0.002665      -0.004885      -0.017423
#            288        -0.023736       -0.015350       0.004902      -0.037573
#
# ...

# %%
import pandas as pd 
df = pd.read_parquet('/home/yangzhilin/backtest/backtest_light/factor_values/xy2.parquet')
df
# Out:
# Uid               1000bonk-usdt  1000floki-usdt  1000lunc-usdt  1000pepe-usdt  \
# date       Label
# 2024-01-02 48          0.020282        0.020676       0.015310       0.021100
#            96          0.037607        0.029769       0.030198       0.030604
#            144         0.079317        0.023945       0.023228       0.046605
#            192         0.044370        0.021674       0.021914       0.041773
#            240         0.005432        0.007436       0.002984       0.008260
# ...                         ...             ...            ...            ...
# 2025-01-01 96          0.003464        0.016422       0.004539       0.050951
#            144        -0.010344        0.002172      -0.005598      -0.001689
#            192        -0.027494        0.003914      -0.005105       0.003567
#            240        -0.019940       -0.002665      -0.004885      -0.017423
#            288        -0.023736       -0.015350       0.004902      -0.037573
#
# ...

# %%
0.003931*2
# Out:
# 0.007862

# %%
sorted_filtered_df = filtered_df.sort_index(level=['date', 'Label'])

sorted_filtered_df
# Out:
# Uid               1000bonk-usdt  1000floki-usdt  1000lunc-usdt  1000pepe-usdt  \
# date       Label
# 2023-11-16 96               NaN             NaN            NaN            NaN
#            96               NaN             NaN            NaN            NaN
#            144              NaN             NaN            NaN            NaN
#            144              NaN             NaN            NaN            NaN
#            192              NaN             NaN            NaN            NaN
# ...                         ...             ...            ...            ...
# 2024-04-30 240        -0.032823       -0.014402       0.003206      -0.000814
#            288        -0.062238       -0.056410      -0.041263      -0.048615
#            288        -0.062238       -0.056410      -0.041263      -0.048615
# 2024-05-01 48         -0.061772       -0.058108      -0.041061      -0.058692
#            48         -0.061772       -0.058108      -0.041061      -0.058692
#
# ...

# %%
import pandas as pd 
df = pd.read_parquet('/home/yangzhilin/backtest/backtest_light/factor_values/xy1.parquet')
# df =  df.loc[df.date < '2023-01-01']
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_parquet('/home/yangzhilin/backtest/backtest_light/factor_values/xy1.parquet')
#       3 # df =  df.loc[df.date < '2023-01-01']
#       4 df
#
# File ~/anaconda3/envs/yangzl39/lib/python3.9/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# ...

# %%
df_ticker = pd.read_parquet('/data-platform/crypto/output_parquet/pv_last.parquet')
df_ticker
# Out:
# Uid               1000bonk-usdt  1000floki-usdt  1000lunc-usdt  1000pepe-usdt  \
# date       Label
# 2019-12-31 1                NaN             NaN            NaN            NaN
#            2                NaN             NaN            NaN            NaN
#            3                NaN             NaN            NaN            NaN
#            4                NaN             NaN            NaN            NaN
#            5                NaN             NaN            NaN            NaN
# ...                         ...             ...            ...            ...
# 2024-12-24 284         0.033450         0.18356        0.12183       0.019345
#            285         0.033502         0.18401        0.12190       0.019404
#            286         0.033344         0.18352        0.12154       0.019321
#            287         0.033145         0.18307        0.12140       0.019258
#            288         0.033128         0.18285        0.12137       0.019269
#
# ...

# %%
df_universe = pd.read_parquet('/data-platform/crypto/output_parquet/pv_universe.parquet')
df_universe
# Out:
# Uid               1000bonk-usdt  1000floki-usdt  1000lunc-usdt  1000pepe-usdt  \
# date       Label
# 2020-01-05 1              False           False          False          False
# 2020-01-06 1              False           False          False          False
# 2020-01-07 1              False           False          False          False
# 2020-01-08 1              False           False          False          False
# 2020-01-09 1              False           False          False          False
# ...                         ...             ...            ...            ...
# 2024-12-26 49              True            True          False           True
#            97              True            True          False           True
#            145             True            True          False           True
#            193             True            True          False           True
#            241             True            True          False           True
#
# ...

# %%
df_intermediate = pd.read_parquet('/home/yangzhilin/backtest/backtest_light/backtest/intermediate/xy.parquet')
df_intermediate
# Out:
#                        pnl   raw_pnl         gmv        ic  benchmark
# date       Label
# 2024-01-01 48    -1.225622 -0.029738   27.063073 -0.300323  -0.022964
#            96    -3.279272 -0.079568   44.210125 -0.828990  -0.007116
#            144   -3.668352 -0.089008   62.454310 -0.886822  -0.001503
#            192   -0.271129 -0.006579   59.521160  0.291443   0.010501
#            240   -1.402191 -0.034023   34.191255 -0.524636   0.016972
# ...                    ...       ...         ...       ...        ...
# 2024-05-01 96    -0.103414 -0.002509  109.852081 -0.127563   0.000494
#            144    0.893184  0.021672   40.831254  0.094967  -0.050220
#            192    0.340143  0.008253   39.729834  0.275395   0.023063
#            240    0.472715  0.011470   77.322126  0.098603  -0.005856
#            288    0.000000  0.000000   38.585907       NaN        NaN
#
# [732 rows x 5 columns]

# %%
df_last = pd.read_parquet('/data-platform/crypto/output_parquet/pv_last.parquet')
df_last
# Out:
# Uid               1000bonk-usdt  1000floki-usdt  1000lunc-usdt  1000pepe-usdt  \
# date       Label
# 2019-12-31 1                NaN             NaN            NaN            NaN
#            2                NaN             NaN            NaN            NaN
#            3                NaN             NaN            NaN            NaN
#            4                NaN             NaN            NaN            NaN
#            5                NaN             NaN            NaN            NaN
# ...                         ...             ...            ...            ...
# 2024-12-29 284         0.031571         0.17684        0.11305       0.018438
#            285         0.031532         0.17704        0.11307       0.018437
#            286         0.031587         0.17707        0.11333       0.018431
#            287         0.031596         0.17713        0.11351       0.018449
#            288         0.031509         0.17668        0.11325       0.018395
#
# ...
